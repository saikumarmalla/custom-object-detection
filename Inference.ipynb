# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.9.0+cu111 (CPU)

# %%
! ls '/content/drive/MyDrive/EV' #'/content/yolov5'
# Out:
# augment.ipynb	 data_analysis.ipynb  res1	 trainval	  yolov5m.yaml
# best.pt		 inference.ipynb      res2	 Untitled0.ipynb
# coco2yolo.ipynb  Inference.ipynb      test_imgs  yolo_data

# %%
# !python detect.py --weights '/content/drive/MyDrive/EV/yolo_data/models/experiment2_best.pt' --img 640 --conf 0.25 --source '/content/drive/MyDrive/EV/test_imgs/'
# Out:
# detect: weights=['/content/drive/MyDrive/EV/yolo_data/models/experiment2_best.pt'], source=/content/drive/MyDrive/EV/test_imgs/, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-39-g5d4258f torch 1.9.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 290 layers, 20856975 parameters, 0 gradients, 48.0 GFLOPs
# image 1/13 /content/drive/MyDrive/EV/test_imgs/image1.jpeg: 384x640 12 persons, Done. (0.604s)
# image 2/13 /content/drive/MyDrive/EV/test_imgs/image10.jpg: 384x640 7 persons, 4 cars, Done. (0.578s)
# image 3/13 /content/drive/MyDrive/EV/test_imgs/image13.jpg: 448x640 4 persons, 3 cars, Done. (0.683s)
# ...

# %%
# !cp -r runs/detect/exp2 '/content/drive/MyDrive/EV/res2'

# %%
Image(filename='runs/detect/exp8/image3.jpeg', width=600)
